# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.8 MB/s eta 0:00:00
# ...

# %%
from datasets import Dataset, Features, Image, Value
import os

# %%
# !git clone https://github.com/huggingface/diffusers
os.chdir('/content/diffusers')
# !python -m pip install -e .

os.chdir('/content/diffusers/examples/controlnet')
# !pip install -r requirements.txt

# !pip install fsspec==2024.10.0
# !pip install torch==2.5.1
# !pip install xformers==0.0.29 triton
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 82072, done.
# remote: Counting objects: 100% (473/473), done.
# remote: Compressing objects: 100% (275/275), done.
# remote: Total 82072 (delta 379), reused 203 (delta 196), pack-reused 81599 (from 3)
# Receiving objects: 100% (82072/82072), 59.89 MiB | 32.14 MiB/s, done.
# Resolving deltas: 100% (60108/60108), done.
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.33.0.dev0-0.editable-py3-none-any.whl size=11241 sha256=9aeec7dcf40973edf74bfc4f406c8510e8ef46c8404f1bf34ffe32559cfb4914
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vw58c41b/wheels/30/15/ca/ab6e88c89d6ba7047b3f155894c6c346e7cf06067fd132ae62
# ...

# %%
# !pip install torch==2.5.1

# %%
# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %%
ls
# Out:
# README_flux.md  requirements_flax.txt  requirements.txt          train_controlnet.py
# README.md       requirements_flux.txt  test_controlnet.py        train_controlnet_sd3.py
# README_sd3.md   requirements_sd3.txt   train_controlnet_flax.py  train_controlnet_sdxl.py
# README_sdxl.md  requirements_sdxl.txt  train_controlnet_flux.py

# %%
# !accelerate launch train_controlnet.py \
 --pretrained_model_name_or_path="stable-diffusion-v1-5/stable-diffusion-v1-5" \
 --output_dir="output_models" \
 --dataset_name=TatsuYmmt/lsun_bedrooms256_50k \
 --resolution=256 \
 --learning_rate=1e-5 \
 --validation_image "./050001.jpg" "./050002.jpg" \
 --validation_prompt "Colorize this greyscale image into colour." "Colorize this greyscale image into colour." \
 --train_batch_size=4
# Out:
# 2025-02-18 03:33:54.681978: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-18 03:33:54.699050: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739849634.720392   13009 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739849634.726984   13009 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !accelerate launch train_controlnet.py \
#  --pretrained_model_name_or_path="stable-diffusion-v1-5/stable-diffusion-v1-5" \
#  --output_dir="output_models" \
#  --dataset_name=TatsuYmmt/celeb256 \
#  --resolution=256 \
#  --learning_rate=1e-5 \
#  --validation_image "./202595.jpg" "./202596.jpg" \
#  --validation_prompt "Colorize this greyscale image into colour." "Colorize this greyscale image into colour." \
#  --train_batch_size=4 \
#  --max_train_steps=20 \
#  --checkpointing_steps=10

# %%
# !accelerate launch infer.py
# Out:
# 2025-02-18 05:09:56.178448: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-18 05:09:56.195107: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739855396.215082   37556 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739855396.221168   37556 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
ls
# Out:
# checkpoint-1000/   checkpoint-1500/  checkpoint-500/   checkpoint-8000/
# checkpoint-10000/  checkpoint-2000/  checkpoint-5000/  checkpoint-8500/
# checkpoint-10500/  checkpoint-2500/  checkpoint-5500/  checkpoint-9000/
# checkpoint-11000/  checkpoint-3000/  checkpoint-6000/  checkpoint-9500/
# checkpoint-11500/  checkpoint-3500/  checkpoint-6500/  config.json
# checkpoint-12000/  checkpoint-4000/  checkpoint-7000/  diffusion_pytorch_model.safetensors
# checkpoint-12500/  checkpoint-4500/  checkpoint-7500/  logs/

# %%
mv ./logs/ "/content/drive/My Drive/Colab Notebooks/checkpoints_LSUN_bedroom"
